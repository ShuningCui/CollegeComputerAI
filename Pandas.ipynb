# %% [markdown]
# 安装pandas，在命令行上使用
#
# pip install pandas
#
# 随后通过 import 引入，使用pandas可以读入csv文件，此处使用了中国省份和城市代码的csv文件作为示例

# %%
import pandas as pd
province_data = pd.read_csv(r".\Province_City_China.csv")
province_data.head()
